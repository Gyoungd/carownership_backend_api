# %% [markdown]
# ## Building DataBase for Car Ownership Analysis
#
# **Data Reference**
#
# Australian Bureau of Statistics. (2024). *Motor vehicle census, Australia* (Catalogue No. 9309.0).
#
# https://www.abs.gov.au/statistics/industry/tourism-and-transport/motor-vehicle-census-australia

# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
# Passanger Car only
path = 'ABS Raw Datasets'
df_2016 = pd.read_excel(path +'/passengercar2016.xlsx')
df_2017 = pd.read_excel(path +'/passengercar2017.xlsx')
df_2018 = pd.read_excel(path +'/passengercar2018.xlsx')
df_2019 = pd.read_excel(path +'/passengercar2019.xlsx')
df_2020 = pd.read_excel(path +'/passengercar2020.xlsx')
df_2021 = pd.read_excel(path +'/passengercar2021.xlsx')

# df_2016 = pd.read_excel(path +'/car2016.xlsx')
# df_2017 = pd.read_excel(path +'/car2017.xlsx')
# df_2018 = pd.read_excel(path +'/car2018.xlsx')
# df_2019 = pd.read_excel(path +'/car2019.xlsx')
# df_2020 = pd.read_excel(path +'/car2020.xlsx')
# df_2021 = pd.read_excel(path +'/car2021.xlsx')
df_2016
# Out:
#                                            Unnamed: 0  \
# 0                          Motor Vehicle Census, 2016
# 1                               State by Vehicle type
# 2                                  Counting: Vehicles
# 3                                                 NaN
# 4                                            Filters:
# 5                                   Default Summation
# 6                                                 NaN
# 7                                        Vehicle type
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
# Cleaning the dataset
# Drop the row 0-6
df_2016 = df_2016.drop(index=range(0, 7))
df_2017 = df_2017.drop(index=range(0, 7))
df_2018 = df_2018.drop(index=range(0, 7))
df_2019 = df_2019.drop(index=range(0, 7))
df_2020 = df_2020.drop(index=range(0, 7))
df_2021 = df_2021.drop(index=range(0, 7))

# Drop the first column and the third column
df_2016 = df_2016.drop(columns=df_2016.columns[0])
df_2017 = df_2017.drop(columns=df_2017.columns[0])
df_2018 = df_2018.drop(columns=df_2018.columns[0])
df_2019 = df_2019.drop(columns=df_2019.columns[0])
df_2020 = df_2020.drop(columns=df_2020.columns[0])
df_2021 = df_2021.drop(columns=df_2021.columns[0])

# Change the column names
df_columns = ['State', 'Total_cars', 'Drop']

df_2016.columns = df_columns
df_2017.columns = df_columns
df_2018.columns = df_columns
df_2019.columns = df_columns
df_2020.columns = df_columns
df_2021.columns = df_columns

# Drop the first two rows
df_2016 = df_2016.iloc[2:,:]
df_2017 = df_2017.iloc[2:,:]
df_2018 = df_2018.iloc[2:,:]
df_2019 = df_2019.iloc[2:,:]
df_2020 = df_2020.iloc[2:,:]
df_2021 = df_2021.iloc[2:,:]

# Drop the 'Drop' column
df_2016 = df_2016.drop(columns=['Drop'])
df_2017 = df_2017.drop(columns=['Drop'])
df_2018 = df_2018.drop(columns=['Drop'])
df_2019 = df_2019.drop(columns=['Drop'])
df_2020 = df_2020.drop(columns=['Drop'])
df_2021 = df_2021.drop(columns=['Drop'])

df_2016
# Out:
#                                                 State Total_cars
# 9                                     NEW SOUTH WALES    4134787
# 10                                           VICTORIA    3666502
# 11                                         QUEENSLAND    2715054
# 12                                    SOUTH AUSTRALIA    1061779
# 13                                  WESTERN AUSTRALIA    1583936
# 14                                           TASMANIA     316902
# 15                                 NORTHERN TERRITORY      95197
# 16                       AUSTRALIAN CAPITAL TERRITORY     240946
# 17                                              Total   13815108
# 18                                                NaN        NaN
# 19                                                NaN        NaN
# 20  Cells in this table have been randomly adjuste...        NaN
# 21  Continuous variables in this table have been r...        NaN
# ...

# %%
# Order by 'State' column
df_2016 = df_2016.sort_values(by='State')
df_2017 = df_2017.sort_values(by='State')
df_2018 = df_2018.sort_values(by='State')
df_2019 = df_2019.sort_values(by='State')
df_2020 = df_2020.sort_values(by='State')
df_2021 = df_2021.sort_values(by='State')

# Remove the missing values
df_2016 = df_2016.dropna()
df_2017 = df_2017.dropna()
df_2018 = df_2018.dropna()
df_2019 = df_2019.dropna()
df_2020 = df_2020.dropna()
df_2021 = df_2021.dropna()

# Reset the index
df_2016 = df_2016.reset_index(drop=True)
df_2017 = df_2017.reset_index(drop=True)
df_2018 = df_2018.reset_index(drop=True)
df_2019 = df_2019.reset_index(drop=True)
df_2020 = df_2020.reset_index(drop=True)
df_2021 = df_2021.reset_index(drop=True)

# Convert 'Total_cars' to numeric
df_2016['Total_cars'] = pd.to_numeric(df_2016['Total_cars'])
df_2017['Total_cars'] = pd.to_numeric(df_2017['Total_cars'])
df_2018['Total_cars'] = pd.to_numeric(df_2018['Total_cars'])
df_2019['Total_cars'] = pd.to_numeric(df_2019['Total_cars'])
df_2020['Total_cars'] = pd.to_numeric(df_2020['Total_cars'])
df_2021['Total_cars'] = pd.to_numeric(df_2021['Total_cars'])

df_2016
# Out:
#                           State  Total_cars
# 0  AUSTRALIAN CAPITAL TERRITORY      240946
# 1               NEW SOUTH WALES     4134787
# 2            NORTHERN TERRITORY       95197
# 3                    QUEENSLAND     2715054
# 4               SOUTH AUSTRALIA     1061779
# 5                      TASMANIA      316902
# 6                         Total    13815108
# 7                      VICTORIA     3666502
# 8             WESTERN AUSTRALIA     1583936

# %%
# Add a new column 'Year' to each dataframe
df_2016['Year'] = 2016
df_2017['Year'] = 2017
df_2018['Year'] = 2018
df_2019['Year'] = 2019
df_2020['Year'] = 2020
df_2021['Year'] = 2021

# Merge all dataframes into one
df_all = pd.concat([df_2016, df_2017, df_2018, df_2019, df_2020, df_2021], ignore_index=True)

# Remove the row with 'Total' in 'State' column
df_all = df_all[df_all['State'] != 'Total']

# Reset the index of the merged dataframe
df_all = df_all.reset_index(drop=True)

df_all
# Out:
#                            State  Total_cars  Year
# 0   AUSTRALIAN CAPITAL TERRITORY      240946  2016
# 1                NEW SOUTH WALES     4134787  2016
# 2             NORTHERN TERRITORY       95197  2016
# 3                     QUEENSLAND     2715054  2016
# 4                SOUTH AUSTRALIA     1061779  2016
# 5                       TASMANIA      316902  2016
# 6                       VICTORIA     3666502  2016
# 7              WESTERN AUSTRALIA     1583936  2016
# 8   AUSTRALIAN CAPITAL TERRITORY      247173  2017
# 9                NEW SOUTH WALES     4217402  2017
# 10            NORTHERN TERRITORY       94141  2017
# 11                    QUEENSLAND     2777112  2017
# 12               SOUTH AUSTRALIA     1075078  2017
# 13                      TASMANIA      324175  2017
# 14                      VICTORIA     3750481  2017
# 15             WESTERN AUSTRALIA     1593003  2017
# 16  AUSTRALIAN CAPITAL TERRITORY      252772  2018
# ...

# %%
df_all['State'].unique()
# Out:
# array(['AUSTRALIAN CAPITAL TERRITORY', 'NEW SOUTH WALES',
#        'NORTHERN TERRITORY', 'QUEENSLAND', 'SOUTH AUSTRALIA', 'TASMANIA',
#        'VICTORIA', 'WESTERN AUSTRALIA'], dtype=object)

# %%
# Change the State naems to abbreviations
state_abbreviations = {
    'AUSTRALIAN CAPITAL TERRITORY': 'ACT',
    'NEW SOUTH WALES': 'NSW',
    'NORTHERN TERRITORY': 'NT',
    'QUEENSLAND': 'QLD',
    'SOUTH AUSTRALIA': 'SA',
    'TASMANIA': 'TAS',
    'VICTORIA': 'VIC',
    'WESTERN AUSTRALIA': 'WA'
}
df_all['State'] = df_all['State'].replace(state_abbreviations)

# Add columns 'carowner_id'
df_all['Carowner_id'] = df_all.index + 1

# Reorder the columns
df_all = df_all[['Carowner_id', 'State', 'Year', 'Total_cars']]

df_all
# Out:
#     Carowner_id State  Year  Total_cars
# 0             1   ACT  2016      240946
# 1             2   NSW  2016     4134787
# 2             3    NT  2016       95197
# 3             4   QLD  2016     2715054
# 4             5    SA  2016     1061779
# 5             6   TAS  2016      316902
# 6             7   VIC  2016     3666502
# 7             8    WA  2016     1583936
# 8             9   ACT  2017      247173
# 9            10   NSW  2017     4217402
# 10           11    NT  2017       94141
# 11           12   QLD  2017     2777112
# 12           13    SA  2017     1075078
# 13           14   TAS  2017      324175
# 14           15   VIC  2017     3750481
# 15           16    WA  2017     1593003
# 16           17   ACT  2018      252772
# 17           18   NSW  2018     4277482
# 18           19    NT  2018      100116
# 19           20   QLD  2018     2837479
# 20           21    SA  2018     1090573
# 21           22   TAS  2018      330910
# ...

# %%
# Find the row state=VIC year = 2019

df_all[df_all['State'] == 'VIC']

# Filter the data by state = VIC and year = 2019
df_all[(df_all['State'] == 'VIC') & (df_all['Year'] == 2021)]
# Out:
#     Carowner_id State  Year  Total_cars
# 46           47   VIC  2021     3970846

# %%
# SAVE THE CLEANED DATAFRAME
df_all.to_csv('paasengercar_ownership_cleaned.csv', index=False)

# %%
# Check the trend of car ownership in Victoria
df_vic = df_all[df_all['State'] == 'VIC']

df_vic

# Plotting the trend of car ownership in Victoria
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_vic, x='Year', y='Total_cars', marker='o')
plt.title('Trend of Car Ownership in Melbourne (2016-2021)')
plt.xlabel('Year')
plt.ylabel('Total Cars')
min_cars = df_vic['Total_cars'].min()
max_cars = df_vic['Total_cars'].max()

n_ticks = 7 
step = int(np.ceil((max_cars - min_cars) / (n_ticks - 1) / 10000) * 10000)
start = int(np.floor(min_cars / step) * step)
end = int(np.ceil(max_cars / step) * step)
yticks = np.arange(start, end + step, step)

#yticklabels = [f'{int(y):,}' for y in yticks]  # f'{y/1e6:.1f}M'
yticklabels = [f'{y/1e6:.1f}M' for y in yticks]

plt.yticks(yticks, yticklabels)

plt.xticks(df_vic['Year'], rotation=45)
plt.grid()

# Save the plot
plt.tight_layout()
plt.savefig('car_ownership_trend_mel.png', dpi=200, bbox_inches='tight')

plt.show()
